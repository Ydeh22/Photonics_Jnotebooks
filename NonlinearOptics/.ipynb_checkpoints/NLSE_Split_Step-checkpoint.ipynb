# %% [markdown]
# ## Imports

# %%
import numpy as np
import pylab as plt
from matplotlib import cm
import seaborn as sns
from tqdm import tqdm

# %% [markdown]
# ## System
#
# > NLSE differential equation
#
# \begin{equation}
# \partial_z A + \frac{\alpha}{2}A+\frac{i}{2}\beta_2 \partial_T^2 A = i \gamma \| A\|^2 A
# \end{equation}
#
# For now, let's suppose $\alpha=0$
#
# \begin{equation}
# \partial_z A = (\hat{D}+\hat{N})A
# \end{equation}
#
# with $\hat{D}=-\frac{i}{2}\beta_2 \partial_T^2$ and $\hat{N}=i \gamma \| A\|^2$
#
#
#
# The operator $\hat{D}$ will be computed in the fourier domain such that $\hat{D}(\omega)=\frac{i}{2}\omega^2\beta_2$
#
# Finally we have at first glance :
#
# \begin{equation}
# A(z+h, T)=e^{h\hat{N}} F^{-1} \cdot e^{h\hat{D}(\omega)} \cdot F \cdot A(z,t)
# \end{equation}
#
# Where $F$ is the Fourier operator, $h$ is the propagation step (of a few meters) and $\beta_2=-D\lambda^2/2\pi c$ wich is related to the optical fiber chromatic dispersion.
#
# > Source : doi:10.1109/ICEE.2007.4287333

# %%
# Constants

c=3e8 # light celerity
l0 = 1.55e-6 # wavelength
nm = 1e-9 # nanometer
ns = 1e-9
km = 5e3 #kilometer
ps = 1e-12 #picosecond
D = 17*ps/nm/km # Dispersion
b2 = -D*l0**2/(2*np.pi*c) # group velocity dispersion (2nd order)
w0 = 1*2*np.pi*1e10
# Parameters

alpha=0.0001 # Losses
gamma=0.78e3 # Nonlinear factor https://ieeexplore.ieee.org/document/7764544

L = 5e3 # Fiber length

Nt= 50000 # Time sampling
Nl = 2000 # Length sampling

# Calculated factors and vectors

h = L/Nl # Lengthstep
dT = 0.001*ns # FWHM
T = np.linspace(-2, 2, Nt)*ns # Pulse local time vector
z = np.arange(0, Nl, 1)*h # Propagation distance vector
P0=220e-3 # W
n = 0.02

dt = T[1]-T[0] # timestep
w =  2*np.pi*c/l0 + np.fft.fftshift(np.fft.fftfreq(Nt, d=dt)) # Pulsation vector # ?? 2*np.pi*c/l0 +
Dw = 0.5*1j*w**2*b2 # Calculated dispersion operator

Noise = np.random.randn(1,Nt) # Amplitude noise vector

A =np.asarray(np.zeros((Nl, Nt), dtype=complex)) # System matrix
B =np.asarray(np.zeros((Nl, Nt), dtype=complex))
#A[0,:]= n*np.sqrt(P0)*Noise + np.sqrt(P0)*(np.exp(-T**2/(2*(dT)**2)))+ np.sqrt(P0)*(np.exp(-(T-0.5*ns)**2/(2*(dT)**2))) # Initial state
A[0,:]= n*np.sqrt(P0)*Noise + np.sqrt(P0)*np.sin(w0*T) # Initial state
B[0,:]=np.fft.fftshift(np.fft.fft(A[0,:]))

# %%
plt.plot(T,np.abs(A[0,:]))
plt.title("Initial pulse")
plt.show()

# %%
for i in tqdm(range(1,Nl)):
    # Fourier domain
    N = 1j*gamma*np.abs(A[i-1,:])**2-0.5*alpha
    Ai = np.exp(0.5*h*N)*A[i-1,:] # half Nonlinearity 1
    Ai = np.fft.fftshift(np.fft.fft(Ai)) # Fourier
    Ai = np.exp(h*Dw)*Ai # Dispersion
    Ai = np.fft.ifft(np.fft.ifftshift(Ai)) # Temporal
    Ai = np.exp(0.5*h*N)*Ai # half Nonlinearity 2
    A[i,:] = Ai
    B[i,:] = np.fft.fftshift(np.fft.fft(Ai))
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 1999/1999 [01:07<00:00, 29.52it/s]

# %%
f = w/(2*np.pi)
extent = [f[0], f[-1], z[-1], z[0]]
plt.imshow(np.abs(A), extent=extent, aspect=1e8, cmap='jet')
plt.xlabel(r"f (Hz)")
plt.ylabel(r"L (m)")

plt.tight_layout()
plt.show()

# %%
plt.plot(T/ns,np.abs(A[0,:]), label='input')
plt.plot(T/ns,np.abs(A[Nl-1,:]), label='output')

plt.grid()
plt.legend()
plt.xlabel("Pulse time (ns)")
plt.ylabel("Pulse Power (W)")
plt.show()

# %%
w[0]
# Out:
# -2499875000001.19

# %%
Dw
# Out:
# array([0.+0.01354091j, 0.+0.0135382j , 0.+0.01353549j, ...,
#        0.+0.01353278j, 0.+0.01353549j, 0.+0.0135382j ])

# %%
N
# Out:
# array([0.+17.06862284j, 0.+15.83780934j, 0. +6.44657317j, ...,
#        0. +5.71969144j, 0.+16.61307259j, 0. +0.36226816j])

# %%
h
# Out:
# 50.0

# %%
c/l0
# Out:
# 193548387096774.2
